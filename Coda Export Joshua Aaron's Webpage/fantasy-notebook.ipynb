// %% [markdown]
// ### Blackrock Further Education Institute
//
// # Game Design - <br> Fundamentals of Object Oriented Programming (5N0541) <br> Mock Exam - Fantasy Kingdom Theme
//
// The exam consists of three sections:
// - **Section A**: 10 Short Questions (10 marks) - Answer ALL questions
// - **Section B**: Programming Task (10 marks) - Answer ONE question
// - **Section C**: Data Organization Task (10 marks) - Answer ONE question
//
// You have 90 minutes to complete this exam. Take your time and read each question carefully.

// %%
// Please type your answers to the lines below

// Student Name:
// Student ID: 
// Course Code:

// %% [markdown]
// # Exam Instructions:
//
// Before you start:
//
// 1. After downloading this file your PC will be disconnected from the network.
//
// 2. Save this file to your desktop. Name it based on your name and student number. For example "J_Soap_20251234.ipynb".
//
// 3. Make sure AutoSave is turned ON. Click "File" in the top left. Ensure "AutoSave" has a tick beside it on the menu.
//
// 4. Write answers in this Notebook in the code boxes provided below each question.
//
// 5. Attempt All Questions.
//
// 6. If there are no line numbers in the code box below hold down Shift and press L to display the line numbers.

// %% [markdown]
// When you are finished:
//
// 1. Ask for your PC to be reconnected to the Network.
//
// 2. Upload this Notebook to Moodle after the exam to the "Exam Upload" section at the top of the Moodle page.
//
// 3. Confirm with the invigilator that this notebook has been uploaded to moodle correctly. Do NOT leave until you have confirmed this.
//
// 4. Make sure you have signed the sign-in sheet.

// %% [markdown]
// ## Section A: Short Questions (10 marks)
// Answer ALL questions. Each question is worth 1 mark. The following is a sample coding cell like the ones below each question for you to type in your answers. Please comment your code and be sure to run your cells to test that your code works.

// %%
// This is a coding cell! When you answer questions you can write them here! 
// If you would like to explain something that doesnt work then you can comment your code like this
// <-- You can show line numbers in all cells by holding down Shift+L

// %% [markdown]
// ### Question 0
// Write one line of code to create a variable named `spellPower` with a value of 75.

// %%
// Write your answer here:


Console.WriteLine($"Power is {spellPower}");

// %% [markdown]
// ### Question 1
// Create an if statement to check if the dragon's health is greater than the hero's attack power.
// Let the user know if the dragon can be defeated or not.

// %%
int dragonHealth = 500;
int heroAttackPower = 120;

// Write your if statement below this line:

// %% [markdown]
// ### Question 2
// Write a for/foreach loop that prints the names of all the adventurers in the list:

// %%
List<string> adventurers = new List<string> { "Wizard", "Knight", "Archer", "Healer" };

// Write your for/foreach loop below this line:

// %% [markdown]
// ### Question 3
// Using the arrays `weapons` and `damages`, write code that finds the index of the most powerful weapon and prints the associated weapon name.

// %%
//array of strings with weapon names
int[] damages = new int[] { 25, 35, 15, 45 };
string[] weapons = new string[] { "Sword", "Axe", "Dagger", "Staff" };
    
// Write your code below this line:

// %% [markdown]
// ### Question 4
// Create a list or array of 5 integers called `potionStrengths`. Print the last item in your list using built-in functions or indexing.

// %%
// declare your list here


// store the last item in your list here


// print the last item in your list

// %% [markdown]
// ### Question 5
// Write the code to create fields and a Constructor called `Wizard` with fields `Name` and `MagicPower` parameters and stores them as properties.

// %%
// Write your class definition here:


// test your program works with the following code
Wizard gandalf = new Wizard("Gandalf", 100);
Console.WriteLine($"Name of Wizard: {gandalf.Name}");
Console.WriteLine($"Magic Power: {gandalf.MagicPower} points");

// %% [markdown]
// ### Question 6
// Given the following class, instantiate two Knight objects (called knight1 and knight2) with different names, weapons and armor classes.

// %%
// create class called Knight with properties Name, Weapon, and ArmorClass
public class Knight
{
    public string Name { get; set; }
    public string Weapon { get; set; }
    public int ArmorClass { get; set; }
    
    // create a constructor for the Knight class
    public Knight(string name, string weapon, int armorClass)
    {
        Name = name;
        Weapon = weapon;
        ArmorClass = armorClass;
    }
}

// instantiate two Knight objects "knight1" and "knight2". Then assign values to their properties


// test your program works with the following code
Console.WriteLine($"Knight {knight1.Name} wields a {knight1.Weapon} and has {knight1.ArmorClass} armor class");
Console.WriteLine($"Knight {knight2.Name} wields a {knight2.Weapon} and has {knight2.ArmorClass} armor class");

// %% [markdown]
// ### Question 7
// Write a method called `calculateDamage()` that takes in two integers, `attackPower` and `multiplier`. Return the two numbers multiplied together.

// %%
// Create your method below this line


// test your program works with the following code
Console.WriteLine($"calculateDamage returns {calculateDamage(10, 3)} when we input 10 and 3");

// %% [markdown]
// ### Question 8
// Write an overloaded method called `CastSpell` within the SpellBook class. This method should take in three integers as input and return their sum.

// %%
// create a class called SpellBook with a CastSpell method that takes two parameters
public class SpellBook
{
    public int CastSpell(int a, int b)
    {
        return a + b;
    }

    // Method to add three integers
    //----- Write your code below this line -----//
    

    //----- Write your code above this line -----//
}

// lets test your code to see that it works!
SpellBook arcaneBook = new SpellBook();
// Using the method that adds two integers
int result1 = arcaneBook.CastSpell(15, 25);
Console.WriteLine("Sum of 15 and 25: " + result1);

// Using the method that adds three integers
int result2 = arcaneBook.CastSpell(15, 25, 35);
Console.WriteLine("Sum of 15, 25, and 35: " + result2);

// %% [markdown]
// ### Question 9
// Create a `Quest` class with 2 fields, a string `Title` and boolean `IsCompleted`. Create a constructor and a `Display` method that displays the fields appropriately.

// %%
// Write your Quest class definition here


// test your program works with the following code
Quest quest1 = new Quest("Slay the Dragon", true);
quest1.Display();
Quest quest2 = new Quest("Find the Lost Amulet", false);
quest2.Display();

// %% [markdown]
// # Section B: Program Design Task (10 marks)
//
// Answer ONE of the TWO questions from this section.

// %% [markdown]
// ### Question B1
//
// Write two functions:
// 1. Function `spellCombine()` that:
// - Takes into two integers
// - Converts them to strings and concatenates them together
// - Return the result.
//
// 2. Function `spellCombine()` that:
// - overloads the previous method
// - takes in an Array of integers
// - concatenates the Array of integers all together
// - returning the result.

// %%
// Write your functions here


// Test code
Console.WriteLine(spellCombine(45, 80));
Console.WriteLine("---------------------");
int[] myArray = {10, 25, 40, 55};
Console.WriteLine(spellCombine(myArray));

// %% [markdown]
// ### Question B2
//
// Write a function `printRuneSymbol()` that takes in a number and prints that many "*" in each row to make a pattern as shown below.
//
// `printRuneSymbol(4)` would give:
//
// `****
//
// ***
//
// **
//
// *
//
// *
//
// **
//
// ***
//
// ****`

// %%
// Write your function here


// Test code
printRuneSymbol(5);

// %% [markdown]
// ## Section C: Data Organisation Task (10 marks)
// Answer ONE of the TWO questions from this section based upon the following class:

// %%
// Run this cell to create the class Realm
public class Realm
{
    public string Name { get; set; }
    public int MagicLevel { get; set; }
    
    public Realm(string name, int magicLevel)
    {
        Name = name;
        MagicLevel = magicLevel;
    }

    public bool isEnchanted()
    {
        if(MagicLevel >= 5){
            return true;
        }else{
            return false;
        }
    }
}

Realm unknown_realm = new Realm("Mystery Realm", 6);
unknown_realm.Display();
Console.WriteLine($"Running isEnchanted() on {unknown_realm.Name} evaluates to: {unknown_realm.isEnchanted()}");

// %% [markdown]
// ### Question C1
// Please complete the following:
//
// -  Create a method `DisplayGuide()` that takes in a list/array of Realms as input, and prints the name of each realm along with its magical status based upon the `isEnchanted()` function.
//
// (e.g., "Avalon - Enchanted", "Wasteland - Mundane").
//
// - Create a list or array of `Realm` Objects called `KingdomGuide` containing the 3 Locations provided (`avalon`,`elfwood`,`shadowlands`).

// %%
// Write your DisplayGuide() method 


// here are some sample realms for your KingdomGuide
Realm avalon = new Realm("Avalon", 8);
Realm elfwood = new Realm("Elfwood", 3);
Realm shadowlands = new Realm("Shadowlands", 9);

// declare your list/array of Realms named KingdomGuide here


// uncomment the code below to test your function and KingdomGuide
// DisplayGuide(KingdomGuide);

// %% [markdown]
// ### Question C2
//
// Please complete the following:
// - Create a method `GetMundaneRealms()` that takes in a list/array of `Realm` Objects returns an integer count of `Realm` objects that are marked as mundane (not enchanted) based upon the `isEnchanted()` function.
// - Create a list or array of `Realm` Objects called `KingdomGuide` containing the 6 Locations provided (`avalon`, `westlands`, `elfwood`, `dragonreach`, `shadowlands`, `frostpeak`).

// %%
// Write your GetMundaneRealms() method here


// here are some sample realms for your KingdomGuide
Realm avalon = new Realm("Avalon", 8);
Realm westlands = new Realm("Westlands", 2);
Realm elfwood = new Realm("Elfwood", 3);
Realm dragonreach = new Realm("Dragonreach", 7);
Realm shadowlands = new Realm("Shadowlands", 9);
Realm frostpeak = new Realm("Frostpeak Mountains", 4);

// declare your list/array of Realms named KingdomGuide here


// uncomment the code below to test your function and KingdomGuide
// int mundane_realms = GetMundaneRealms(KingdomGuide);
// Console.WriteLine($"There is/are {mundane_realms} mundane realm(s) in our guide!");

// %% [markdown]
// # End of Examination
