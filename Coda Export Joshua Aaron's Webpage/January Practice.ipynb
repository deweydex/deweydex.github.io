// %% [markdown]
// # January Practice
//
// The following practice problems are similar to what one would expect to see on an exam or an assignment. Please complete the following in this Polyglot Notebook. You may use whatever resources you would like to help you complete them, though I recommend having a look at the C# Cheat Sheet on Codecademy or using the documentation in Visual Studio. Please avoid the use of a LLM Based AI model for this task. If you have any questions please raise your hand and I will come around.
//
// Remember: you are highly encouraged to start by writing pseudo-code (or just sentences describing what you would like to code). The More you write (in English, not code) the easier it will be to translate into code.

// %% [markdown]
// # Challenge 1
//
// See if you can write and test a function called `same_length` which accepts two lists as input and returns (a Boolean) `True` if the two lists are the same size and `False` otherwise.

// %%
/*
You can write your psuedo-code and notes here!
*/


// Your code goes here! :) Be sure to include comments that explain your choices and ideas!

// %% [markdown]
// What test cases might be important to check here?

// %%
/*
You can write your psuedo-code and notes here!
*/


// Your code goes here! :) Be sure to include comments that explain your choices and ideas!

// %% [markdown]
// # Challenge 2
//
// See if you can write and test a function called `list_addition` that accepts two lists of integers as its arguments and returns a new list containing the sum of each entry in the first list with each entry in the second list. Be sure to check that the lists are of the same length! if they are not, return an empty list.
//
// As an example list_addition([12, 34, 56], [-4, 91, 0]) would return [8, 125, 56].

// %%
/*
You can write your psuedo-code and notes here!
*/


// Your code goes here! :) Be sure to include comments that explain your choices and ideas!

// %% [markdown]
// What test cases might be important to check here?

// %%
/*
You can write your psuedo-code and notes here!
*/


// Your code goes here! :) Be sure to include comments that explain your choices and ideas!

// %% [markdown]
// # Challenge 3
//
// Let's try to code a function that implements digit addition using lists. To do this, lets create a function `gradeschool_addition` that takes in two lists of the same length which contain only single digit positive integers as each list element. This function would return a new list (potentially a slightly longer list) which represents the digit (gradeschool) addition of the two lists: so adding 1234 + 2345 would give 3579 normally, but in our case we would have `gradeschool_addition([1,2,3,4],[2,3,4,5]) -> [3,5,7,9]` (see how the lists are basically numbers)?

// %%
/*
You can write your psuedo-code and notes here!
*/


// Your code goes here! :) Be sure to include comments that explain your choices and ideas!

// %% [markdown]
// This might need a few different test cases! As a bonus, can you write a function that accepts lists of different length and handles them appropriately? How about an equivalent function for substraction?

// %%
/*
You can write your psuedo-code and notes here!
*/


// Your code goes here! :) Be sure to include comments that explain your choices and ideas!

// %% [markdown]
// # Challenge 4 (More Advanced: maybe try this one at home!)
//
// Can you make a similar function to Challenge Three but that implements gradeschool multiplication? Lets call it `gradeschool_multiplication'... What kind of changes did you need to make to get this working?

// %%
/*
You can write your psuedo-code and notes here!
*/


// Your code goes here! :) Be sure to include comments that explain your choices and ideas!

// %% [markdown]
// This might need a few different test cases! As a bonus, can you write a function that accepts lists of different length and handles them appropriately? How about an equivalent function for division--that one might take significant changes to your previous method!

// %%
/*
You can write your psuedo-code and notes here!
*/


// Your code goes here! :) Be sure to include comments that explain your choices and ideas!
