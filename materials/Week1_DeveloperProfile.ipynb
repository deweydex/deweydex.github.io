# %% [markdown]
# # Week 1 – Personal & Professional Development: Who Are You as a Developer?
#
# This notebook is part of our *Personal and Professional Development* journey.
# For the next few weeks, we’re not just thinking about *what* we know in computer science, but also *how* we want to grow as developers, professionals, and people.
#
# Today’s focus:
# - taking stock of where we are now,
# - practising how to describe ourselves as developers,
# - learning how to give and receive feedback.
#
# ---
#
# ## Why are we doing this?
#
# In computer science, technical skills matter. But equally important is how you present yourself and how you reflect on your growth.
# Employers, collaborators, and even your future self will want to know:
#
# - *What can you do?*
# - *What are you interested in?*
# - *Where are you heading next?*
#
# This is not about “selling yourself” in a shallow way. It’s about **building an honest, clear picture** of your strengths and aspirations.
# And it’s also about developing habits of reflection and communication that will help you in your university projects and future jobs.

# %% [markdown]
# ## Task 1 – Skills Audit
#
# Think of this as a **snapshot** of your current abilities.
# Just write down what comes to mind under these categories:
#
# - Programming languages you know (and how comfortable you are with each).
# - Tools and technologies you’ve used (IDEs, version control, platforms).
# - Soft skills you bring to group projects (teamwork, persistence, problem solving, communication).
# - Projects you have worked on or will have finished by the end of the year (or would like to do this year!)
# - Areas you’d *like* to grow in (technologies you’re curious about, skills you want to practice).
#
# Go ahead and Add a new text cell below include a list of each!

# %% [markdown]
# ## Task 2 – Developer Profile (Markdown)
#
# Now we’ll write a short **developer profile**.
# This is like the “About Me” section you might put at the top of a GitHub page.
# It should be professional but personal — a window into how you think about your work.
#
# Think about:
# - Who are you as a student and developer?
# - What kind of projects or problems interest you?
# - What are you curious to learn next?
# - What else do you want people to know about you?

# %% [markdown]
# # Example Developer Profile
#
# Hi, I’m Sandra 👋
# - 🎓 I’m a Level 6 Computer Science student.
# - 💻 I enjoy working with Python and learning about web technologies.
# - 🚀 My current goal is to build small apps and contribute to open source.
# - 🎸 Fun fact: I also play guitar!

# %% [markdown]
# ## Task 3 – Feedback
#
# During class:
# - Share your Developer Profile with a partner.
# - Give them one suggestion for making it clearer or stronger.
# - Record the feedback you received below.

# %% [markdown]
# **Feedback I received:**
# - …
#
# **My response / what I will change:**
# - …

# %% [markdown]
# ## Task 4 – Reflection
#
# Take 5–10 minutes to reflect:
# - What surprised you about your own skills audit?
# - How did it feel to describe yourself as a developer?
# - What did you learn from giving or receiving feedback?
# - How might this profile evolve over the next year?

# %% [markdown]
# # Resources: GitHub Basics
# - [GitHub: Getting started with your profile](https://docs.github.com/en/get-started/start-your-journey/setting-up-your-profile)
# - [About READMEs](https://docs.github.com/en/get-started/start-your-journey/about-readmes)
# - [Markdown Cheat Sheet](https://www.markdownguide.org/cheat-sheet/)
